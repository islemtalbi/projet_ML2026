# %%
import numpy as np
import pandas as pd

# %%
path = r'C:\Users\hp\Downloads\bank.csv' 
df = pd.read_csv(path, sep=';')

# Vérification immédiate
print(df.head())
# Out:
#   Cell In[3], line 1
#     df = pd.read_csv('C:\Users\hp\Downloads\Tp 7_clustering_Bank-20260407', sep=';')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
